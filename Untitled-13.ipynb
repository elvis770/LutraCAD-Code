# %%
import pyvista as pv
import numpy as np
import os
import pandas as pd

def extract_geometric_features(stl_path):
    try:
        # Load the STL file
        mesh = pv.read(stl_path)
        
        # Get the bounding box dimensions
        bounds = mesh.bounds
        length = bounds[1] - bounds[0]
        width = bounds[3] - bounds[2]
        height = bounds[5] - bounds[4]
        
        # Calculate the volume
        volume = mesh.volume
        
        return {
            'Length': length,
            'Width': width,
            'Height': height,
            'Volume': volume
        }
    except Exception as e:
        print(f"Error extracting features from {stl_path}: {e}")
        return None

def is_valid_foot_scan(features):
    # Define thresholds for valid foot scans
    min_length = 100  # Example threshold in mm
    max_length = 400  # Example threshold in mm
    min_width = 50    # Example threshold in mm
    max_width = 200   # Example threshold in mm
    min_height = 10   # Example threshold in mm
    max_height = 200  # Example threshold in mm
    min_volume = 1000  # Example threshold in cubic mm
    max_volume = 1000000  # Example threshold in cubic mm
    
    if (min_length <= features['Length'] <= max_length and
        min_width <= features['Width'] <= max_width and
        min_height <= features['Height'] <= max_height and
        min_volume <= features['Volume'] <= max_volume):
        return True
    return False

def visualize_and_save_screenshot(mesh, output_path):
    try:
        # Create a Plotter with off-screen rendering enabled
        plotter = pv.Plotter(off_screen=True)
        
        # Add the mesh to the plotter
        plotter.add_mesh(mesh)
        
        # Save a screenshot
        plotter.screenshot(output_path)
        
        # Close the plotter
        plotter.close()
    except Exception as e:
        print(f"Error visualizing mesh: {e}")

# Base directory containing subfolders
base_dir = '/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011'

# Data structure to store information for the table
data = []

# Iterate over each subfolder in the base directory
for subfolder in os.listdir(base_dir):
    subfolder_path = os.path.join(base_dir, subfolder)
    if os.path.isdir(subfolder_path):
        foot_scans = [f for f in os.listdir(subfolder_path) if f.endswith('.stl') and not f.endswith('library.stl')]

        # Check for valid foot scans
        for foot_scan in foot_scans:
            foot_scan_path = os.path.join(subfolder_path, foot_scan)
            features = extract_geometric_features(foot_scan_path)
            if features and is_valid_foot_scan(features):
                foot_scan_img = os.path.join(subfolder_path, f'{foot_scan}.png')
                mesh = pv.read(foot_scan_path)
                visualize_and_save_screenshot(mesh, foot_scan_img)
                
                # Find all the insoles in the same folder
                insoles = [f for f in os.listdir(subfolder_path) if f.endswith('library.stl')]
                insole_images = []
                for insole in insoles:
                    insole_path = os.path.join(subfolder_path, insole)
                    insole_img = os.path.join(subfolder_path, f'{insole}.png')
                    mesh = pv.read(insole_path)
                    visualize_and_save_screenshot(mesh, insole_img)
                    insole_images.append(insole_img)

                data.append({
                    'Subfolder': subfolder,
                    'Foot Scan': foot_scan,
                    'Foot Scan Image': foot_scan_img,
                    'Insole': ', '.join(insoles),
                    'Insole Images': ', '.join(insole_images),
                    'Foot Length': features['Length'],
                    'Foot Width': features['Width'],
                    'Foot Height': features['Height'],
                    'Foot Volume': features['Volume']
                })

# Create a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to CSV, HDF5, and pickle files
csv_path = 'all_insoles_foot_scan_table.csv'
df.to_csv(csv_path, index=False)

hdf5_path = 'all_insoles_foot_scan_table.h5'
df.to_hdf(hdf5_path, key='data', mode='w')

pickle_path = 'all_insoles_foot_scan_table.pkl'
df.to_pickle(pickle_path)

# Save the DataFrame as an HTML file
html_path = 'all_insoles_foot_scan_table.html'
df.to_html(html_path, escape=False, formatters={
    'Foot Scan Image': lambda x: f'<img src="{x}" width="100"/>',
    'Insole Images': lambda x: '<br>'.join([f'<img src="{img}" width="100"/>' for img in x.split(', ')])
})

# Display the table in Jupyter Notebook
from IPython.display import display, HTML
display(HTML(df.to_html(escape=False, formatters={
    'Foot Scan Image': lambda x: f'<img src="{x}" width="100"/>',
    'Insole Images': lambda x: '<br>'.join([f'<img src="{img}" width="100"/>' for img in x.split(', ')])
})))
# Out:
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# 2024-06-11 15:04:29.296 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x47ba21340 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.300 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x45b6f2ba0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.355 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x380d7eba0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.357 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x380d18b60 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.385 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x380d7eba0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.387 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x380d598c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.414 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x380d7eba0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.416 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x474f584d0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.455 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x380d80ee0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.457 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x380d7eba0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-11 15:04:29.487 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x11fe81e90 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.489 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x11fef0540 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.518 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x39422f7e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.519 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x39422f7e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.561 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x39422f7e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.563 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x474f39620 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.595 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x39424dd90 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.596 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x39422f7e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.626 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x39422f7e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.628 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x39424dd90 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.670 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x380d894b0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.671 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x380d78970 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.703 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x494af3010 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.704 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x494ae0d60 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.736 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x380d61660 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.737 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x380dca340 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-11 15:04:29.777 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x380dca340 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.779 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x380dd7510 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.808 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x11fe74590 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.809 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x11fe81e90 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.840 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x380dffca0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.842 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x380dffca0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.929 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab11e120 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.931 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab112790 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.960 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab11ca30 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-11 15:04:29.961 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab11e120 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.992 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab11e120 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:29.994 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab118e00 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.025 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x43287b320 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.027 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x474fb5810 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.055 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x43286f760 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.057 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x432879cc0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Context leak detected, msgtracer returned -1
# 2024-06-11 15:04:30.089 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4328a7990 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.091 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4328a26b0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Context leak detected, msgtracer returned -1
# 2024-06-11 15:04:30.121 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4328a7990 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.122 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x432899e60 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.152 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4328d1b30 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.153 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4328cc620 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.185 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b07cded0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.186 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b079e270 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.214 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4328d02a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.216 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4328d0480 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-11 15:04:30.338 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c20524a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.340 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c20524a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.369 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b07edc10 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.370 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c204d6d0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.402 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab174fa0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.403 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab1539c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.435 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4328fd5b0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.437 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c2088e10 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.468 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x432891870 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.469 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4328fbec0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.505 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c20daeb0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.506 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d0f04210 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.534 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4328ee000 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.536 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4328ee000 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.568 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4328ee190 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.569 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
#  (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4328ee2c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.601 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d0fd86a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.603 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d0fb9390 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.630 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d1029e40 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.632 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4a3a23f80 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.677 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab1ddb00 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.679 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab1d8820 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.713 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab1cfec0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.714 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab1ddb00 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.743 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab1cfec0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.745 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab1d8820 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.777 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab1d3cd0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.779 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab1d3cd0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.808 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab1cd580 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.809 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab1f9530 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.846 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d1043920 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-11 15:04:30.847 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab1a2910 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.880 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4a3a23f80 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.883 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d1043920 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.912 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d1042230 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.914 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d1043920 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.948 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x494b885e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.951 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d103e600 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.979 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d1042230 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:30.981 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4a3a45ca0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:31.040 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ab1a4ca0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:31.042 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x494bd16e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:31.075 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4f635c830 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:31.077 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4a3a48170 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-11 15:04:31.110 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4f637b750 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:31.112 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4f637a990 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:31.145 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d1039a80 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:31.146 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4a3a56cd0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:31.185 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4a3a17050 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:31.187 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d105f1c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:31.219 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d1039a80 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:31.221 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d1061240 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:31.252 python[5553:171585] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d1039760 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:31.254 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d10361c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:31.282 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4a3a12600 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# ...
# 2024-06-11 15:04:32.486 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x5505d13c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:32.487 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x5505cbfa0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:32.525 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52d1c3230 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:32.527 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52d1c6950 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:32.557 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52d1e9430 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:32.558 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52d1f6bb0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:32.589 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52d1f6bb0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:32.591 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52d1f1350 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:32.620 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x566b28110 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:32.622 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x566b22f70 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:32.657 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x566b1a630 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:32.659 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x566b28110 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:32.688 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x566b24990 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-11 15:04:32.689 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x566b24990 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:32.720 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x55f3f3ad0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:32.721 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x55f3f4af0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:32.752 python[5553:171576] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x569470d30 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 15:04:32.754 python[5553:171581] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x5694547f0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Subfolder</th>
#       <th>Foot Scan</th>
#       <th>Foot Scan Image</th>
#       <th>Insole</th>
#       <th>Insole Images</th>
#       <th>Foot Length</th>
#       <th>Foot Width</th>
#       <th>Foot Height</th>
#       <th>Foot Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Anonymous_20240507043443</td>
#       <td>31e01ae6-bc67-4235-b1c6-944f8c325729_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/31e01ae6-bc67-4235-b1c6-944f8c325729_0_document.stl.png" width="100"/></td>
#       <td>67_library.stl, 49_library.stl, 29_library.stl, 91_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/67_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/49_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/29_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/91_library.stl.png" width="100"/></td>
#       <td>246.220482</td>
#       <td>98.687160</td>
#       <td>50.116524</td>
#       <td>685916.257100</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Anonymous_20240507043443</td>
#       <td>0169f5c3-dc66-4de0-8e71-d2108dbabe63_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/0169f5c3-dc66-4de0-8e71-d2108dbabe63_1_document.stl.png" width="100"/></td>
#       <td>67_library.stl, 49_library.stl, 29_library.stl, 91_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/67_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/49_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/29_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/91_library.stl.png" width="100"/></td>
#       <td>242.586243</td>
#       <td>98.942276</td>
#       <td>50.403454</td>
#       <td>701255.889287</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Anonymous_20240506033002</td>
#       <td>3414bbfe-685b-4462-8071-05ef9d40ce0f_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/3414bbfe-685b-4462-8071-05ef9d40ce0f_0_document.stl.png" width="100"/></td>
#       <td>26_library.stl, 67_library.stl, 49_library.stl, 1_library.stl, 19_library.stl, 22_library.stl, 28_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/26_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/67_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/49_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/1_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/19_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/22_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/28_library.stl.png" width="100"/></td>
#       <td>234.057808</td>
#       <td>92.513699</td>
#       <td>28.666253</td>
#       <td>21815.959887</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Anonymous_20240506033002</td>
#       <td>132b9f60-57bb-4e44-b480-0cad7abd106c_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/132b9f60-57bb-4e44-b480-0cad7abd106c_1_document.stl.png" width="100"/></td>
#       <td>26_library.stl, 67_library.stl, 49_library.stl, 1_library.stl, 19_library.stl, 22_library.stl, 28_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/26_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/67_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/49_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/1_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/19_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/22_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/28_library.stl.png" width="100"/></td>
#       <td>229.371590</td>
#       <td>85.996262</td>
#       <td>33.755031</td>
#       <td>29972.094611</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Anonymous_20240507025604</td>
#       <td>13e80473-7d0b-4d2b-aad0-53550c5eda9b_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507025604/13e80473-7d0b-4d2b-aad0-53550c5eda9b_0_document.stl.png" width="100"/></td>
#       <td>67_library.stl, 49_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507025604/67_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507025604/49_library.stl.png" width="100"/></td>
#       <td>256.039490</td>
#       <td>91.555882</td>
#       <td>36.582973</td>
#       <td>46328.524155</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Anonymous_20240507025604</td>
#       <td>c3a2d5ce-1750-41d8-aa4b-eac754ed53e6_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507025604/c3a2d5ce-1750-41d8-aa4b-eac754ed53e6_1_document.stl.png" width="100"/></td>
#       <td>67_library.stl, 49_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507025604/67_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507025604/49_library.stl.png" width="100"/></td>
#       <td>241.652771</td>
#       <td>110.635677</td>
#       <td>54.769722</td>
#       <td>86008.301317</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Anonymous_20240506021423</td>
#       <td>7cdc0bf2-0f5d-4567-be3d-2bd4793c3f6f_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506021423/7cdc0bf2-0f5d-4567-be3d-2bd4793c3f6f_1_document.stl.png" width="100"/></td>
#       <td>69_library.stl, 58_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506021423/69_library.stl.png" width="100"/><br><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506021423/58_library.stl.png" width="100"/></td>
#       <td>260.731010</td>
#       <td>100.715412</td>
#       <td>44.422279</td>
#       <td>611914.467397</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Anonymous_20240506021423</td>
#       <td>d44c0998-ab31-49bc-962e-3f917657c518_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_2024050602142
