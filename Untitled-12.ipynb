# %%
import pyvista as pv
import numpy as np
import os
import pandas as pd

def extract_geometric_features(stl_path):
    try:
        # Load the STL file
        mesh = pv.read(stl_path)
        
        # Get the bounding box dimensions
        bounds = mesh.bounds
        length = bounds[1] - bounds[0]
        width = bounds[3] - bounds[2]
        height = bounds[5] - bounds[4]
        
        # Calculate the volume
        volume = mesh.volume
        
        return {
            'Length': length,
            'Width': width,
            'Height': height,
            'Volume': volume
        }
    except Exception as e:
        print(f"Error extracting features from {stl_path}: {e}")
        return None

def is_valid_foot_scan(features):
    # Define thresholds for valid foot scans
    min_length = 100  # Example threshold in mm
    max_length = 400  # Example threshold in mm
    min_width = 50    # Example threshold in mm
    max_width = 200   # Example threshold in mm
    min_height = 10   # Example threshold in mm
    max_height = 200  # Example threshold in mm
    min_volume = 1000  # Example threshold in cubic mm
    max_volume = 1000000  # Example threshold in cubic mm
    
    if (min_length <= features['Length'] <= max_length and
        min_width <= features['Width'] <= max_width and
        min_height <= features['Height'] <= max_height and
        min_volume <= features['Volume'] <= max_volume):
        return True
    return False

def visualize_and_save_screenshot(mesh, output_path):
    try:
        # Create a Plotter with off-screen rendering enabled
        plotter = pv.Plotter(off_screen=True)
        
        # Add the mesh to the plotter
        plotter.add_mesh(mesh)
        
        # Save a screenshot
        plotter.screenshot(output_path)
        
        # Close the plotter
        plotter.close()
    except Exception as e:
        print(f"Error visualizing mesh: {e}")

# Base directory containing subfolders
base_dir = '/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011'

# Data structure to store information for the table
data = []

# Iterate over each subfolder in the base directory
for subfolder in os.listdir(base_dir):
    subfolder_path = os.path.join(base_dir, subfolder)
    if os.path.isdir(subfolder_path):
        foot_scans = [f for f in os.listdir(subfolder_path) if f.endswith('.stl') and not f.endswith('library.stl')]

        # Check for valid foot scans
        for foot_scan in foot_scans:
            foot_scan_path = os.path.join(subfolder_path, foot_scan)
            features = extract_geometric_features(foot_scan_path)
            if features and is_valid_foot_scan(features):
                foot_scan_img = os.path.join(subfolder_path, f'{foot_scan}.png')
                mesh = pv.read(foot_scan_path)
                visualize_and_save_screenshot(mesh, foot_scan_img)
                
                # Find the insoles in the same folder
                insoles = [f for f in os.listdir(subfolder_path) if f.endswith('library.stl')]
                insole_images = []
                for insole in insoles[:2]:  # Only take up to 2 insoles
                    insole_path = os.path.join(subfolder_path, insole)
                    insole_img = os.path.join(subfolder_path, f'{insole}.png')
                    mesh = pv.read(insole_path)
                    visualize_and_save_screenshot(mesh, insole_img)
                    insole_images.append(insole_img)

                # Ensure we have exactly 2 insole images
                while len(insole_images) < 2:
                    insole_images.append(None)
                    
                data.append({
                    'Subfolder': subfolder,
                    'Foot Scan': foot_scan,
                    'Foot Scan Image': foot_scan_img,
                    'Insole 1': insoles[0] if len(insoles) > 0 else None,
                    'Insole Image 1': insole_images[0],
                    'Insole 2': insoles[1] if len(insoles) > 1 else None,
                    'Insole Image 2': insole_images[1],
                    'Foot Length': features['Length'],
                    'Foot Width': features['Width'],
                    'Foot Height': features['Height'],
                    'Foot Volume': features['Volume']
                })

# Create a DataFrame
df = pd.DataFrame(data)

# Remove exact duplicate rows (if any)
df = df.drop_duplicates()

# Save the DataFrame to CSV, HDF5, and pickle files
csv_path = 'merged_foot_scan_insole_table.csv'
df.to_csv(csv_path, index=False)

hdf5_path = 'merged_foot_scan_insole_table.h5'
df.to_hdf(hdf5_path, key='data', mode='w')

pickle_path = 'merged_foot_scan_insole_table.pkl'
df.to_pickle(pickle_path)

# Save the DataFrame as an HTML file
html_path = 'merged_foot_scan_insole_table.html'
df.to_html(html_path, escape=False, formatters={
    'Foot Scan Image': lambda x: f'<img src="{x}" width="100"/>',
    'Insole Image 1': lambda x: f'<img src="{x}" width="100"/>',
    'Insole Image 2': lambda x: f'<img src="{x}" width="100"/>'
})

# Display the table in Jupyter Notebook
from IPython.display import display, HTML
display(HTML(df.to_html(escape=False, formatters={
    'Foot Scan Image': lambda x: f'<img src="{x}" width="100"/>',
    'Insole Image 1': lambda x: f'<img src="{x}" width="100"/>',
    'Insole Image 2': lambda x: f'<img src="{x}" width="100"/>'
})))
# Out:
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# 2024-06-11 14:57:18.172 python[5267:166395] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x48fe75f50 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.176 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x48fe7b2a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.233 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x42622d130 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.238 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x478472340 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.281 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4262788e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.283 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x426273600 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.314 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x49702f7e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.316 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4970240c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.346 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x426297a20 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.347 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x46ba93e80 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.384 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x426297a20 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.385 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x426297ae0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.415 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x426297ae0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-11 14:57:18.417 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x426297a20 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.446 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x42620f210 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.447 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4262b9ee0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.504 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x42629cff0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.505 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x42629cff0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.542 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x42620f210 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.544 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x42629cff0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.574 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4262ba1a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.576 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x42629cff0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.610 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4262fc9f0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.612 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4262f7710 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.641 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x42629cfc0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.643 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4262c6b00 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.673 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4262fa690 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.675 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4262ef4b0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-11 14:57:18.715 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b3954420 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.716 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b3955650 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.747 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b102e9c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.749 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b104ea90 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.779 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b39ad7c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.781 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4bd812a30 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.821 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b1054060 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.823 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b1064da0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.853 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b10505f0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.855 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b10505f0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.885 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c50202c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.887 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c501afe0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.929 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x46baad1e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.931 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4bd860040 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Context leak detected, msgtracer returned -1
# 2024-06-11 14:57:18.962 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b1099ef0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.963 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b1099ef0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Context leak detected, msgtracer returned -1
# 2024-06-11 14:57:18.991 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b10987b0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:18.993 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b10ef420 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.029 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b10eac60 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.031 python[5267:166399] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4b1099ef0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-11 14:57:19.063 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c5089e10 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.065 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c5084b30 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.094 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4bd85d650 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.096 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4bd8e64e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.139 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c509b7f0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.141 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c509b7f0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.172 python[5267:164119] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c50991f0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.174 python[5267:164119] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c50991f0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.206 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c50b4520 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.208 python[5267:164119] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d701e590 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.242 python[5267:164119] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c50e4fe0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.244 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c50dfcc0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.272 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c50e4c30 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-11 14:57:19.274 python[5267:164119] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c50ccb20 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.305 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x46bab0220 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.306 python[5267:164119] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c50d1ec0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.353 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4e0e9d420 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.355 python[5267:164119] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4e0e9d420 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.388 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d7033650 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.389 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d7042fe0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.422 python[5267:164119] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d7041da0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.424 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d7040fc0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.460 python[5267:164119] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c50e6a50 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.462 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x373446360 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.493 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c50d5060 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.495 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4c50e6a50 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.525 python[5267:164121] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d706d9c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-11 14:57:19.527 python[5267:164119] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x373446330 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-11 14:57:19.562 python[5267:164119] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4