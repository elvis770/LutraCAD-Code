# %%
import pyvista as pv
import numpy as np
import os
import pandas as pd

def extract_geometric_features(stl_path):
    try:
        # Load the STL file
        mesh = pv.read(stl_path)
        
        # Get the bounding box dimensions
        bounds = mesh.bounds
        length = bounds[1] - bounds[0]
        width = bounds[3] - bounds[2]
        height = bounds[5] - bounds[4]
        
        # Calculate the volume
        volume = mesh.volume
        
        return {
            'Length': length,
            'Width': width,
            'Height': height,
            'Volume': volume
        }
    except Exception as e:
        print(f"Error extracting features from {stl_path}: {e}")
        return None

def is_valid_foot_scan(features):
    # Define thresholds for valid foot scans
    min_length = 100  # Example threshold in mm
    max_length = 400  # Example threshold in mm
    min_width = 50    # Example threshold in mm
    max_width = 200   # Example threshold in mm
    min_height = 10   # Example threshold in mm
    max_height = 200  # Example threshold in mm
    min_volume = 1000  # Example threshold in cubic mm
    max_volume = 1000000  # Example threshold in cubic mm
    
    if (min_length <= features['Length'] <= max_length and
        min_width <= features['Width'] <= max_width and
        min_height <= features['Height'] <= max_height and
        min_volume <= features['Volume'] <= max_volume):
        return True
    return False

def is_valid_insole(features):
    # Define thresholds for valid insoles
    min_length = 200  # Example threshold in mm
    max_length = 300  # Example threshold in mm
    min_width = 50    # Example threshold in mm
    max_width = 150   # Example threshold in mm
    
    if (min_length <= features['Length'] <= max_length and
        min_width <= features['Width'] <= max_width):
        return True
    return False

def calculate_curvature(mesh):
    # Placeholder function for calculating the curvature of the insole
    # Implement an actual curvature calculation if necessary
    curvature = 0
    return curvature

def filter_and_select_best_insoles(insole_paths):
    # Extract features and calculate curvature for each insole
    insoles = []
    for insole_path in insole_paths:
        features = extract_geometric_features(insole_path)
        if features and is_valid_insole(features):
            mesh = pv.read(insole_path)
            curvature = calculate_curvature(mesh)
            insoles.append((insole_path, features, curvature))
    
    # Sort insoles by length, width, and curvature
    insoles.sort(key=lambda x: (x[1]['Length'], x[1]['Width'], x[2]))

    # Retain only the top two insoles
    return insoles[:2]

def visualize_and_save_screenshot(mesh, output_path):
    try:
        # Create a Plotter with off-screen rendering enabled
        plotter = pv.Plotter(off_screen=True)
        
        # Add the mesh to the plotter
        plotter.add_mesh(mesh)
        
        # Save a screenshot
        plotter.screenshot(output_path)
        
        # Close the plotter
        plotter.close()
    except Exception as e:
        print(f"Error visualizing mesh: {e}")

# Base directory containing subfolders
base_dir = '/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011'

# Data structure to store information for the table
data = []

# Iterate over each subfolder in the base directory
for subfolder in os.listdir(base_dir):
    subfolder_path = os.path.join(base_dir, subfolder)
    if os.path.isdir(subfolder_path):
        foot_scans = [f for f in os.listdir(subfolder_path) if f.endswith('.stl') and not f.endswith('library.stl')]

        # Check for valid foot scans
        for foot_scan in foot_scans:
            foot_scan_path = os.path.join(subfolder_path, foot_scan)
            features = extract_geometric_features(foot_scan_path)
            if features and is_valid_foot_scan(features):
                foot_scan_img = os.path.join(subfolder_path, f'{foot_scan}.png')
                mesh = pv.read(foot_scan_path)
                visualize_and_save_screenshot(mesh, foot_scan_img)
                data.append({
                    'Subfolder': subfolder,
                    'Foot Scan': foot_scan,
                    'Foot Scan Image': foot_scan_img,
                    'Insole': None,
                    'Insole Image': None,
                    'Foot Length': features['Length'],
                    'Foot Width': features['Width'],
                    'Foot Height': features['Height'],
                    'Foot Volume': features['Volume']
                })

                # Visualize and filter insoles in the same folder
                insole_paths = [os.path.join(subfolder_path, f) for f in os.listdir(subfolder_path) if f.endswith('library.stl')]
                best_insoles = filter_and_select_best_insoles(insole_paths)
                for insole_path, insole_features, _ in best_insoles:
                    insole_img = os.path.join(subfolder_path, f'{os.path.basename(insole_path)}.png')
                    mesh = pv.read(insole_path)
                    visualize_and_save_screenshot(mesh, insole_img)
                    data.append({
                        'Subfolder': subfolder,
                        'Foot Scan': None,
                        'Foot Scan Image': None,
                        'Insole': os.path.basename(insole_path),
                        'Insole Image': insole_img,
                        'Insole Length': insole_features['Length'],
                        'Insole Width': insole_features['Width'],
                        'Insole Height': insole_features['Height'],
                        'Insole Volume': insole_features['Volume']
                    })

# Create a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to CSV, HDF5, and pickle files
csv_path = 'filtered_foot_scan_insole_table.csv'
df.to_csv(csv_path, index=False)

hdf5_path = 'filtered_foot_scan_insole_table.h5'
df.to_hdf(hdf5_path, key='data', mode='w')

pickle_path = 'filtered_foot_scan_insole_table.pkl'
df.to_pickle(pickle_path)

# Save the DataFrame as an HTML file
html_path = os.path.join(base_dir, 'filtered_foot_scan_insole_table.html')
df.to_html(html_path, escape=False, formatters={
    'Foot Scan Image': lambda x: f'<img src="{x}" width="100"/>',
    'Insole Image': lambda x: f'<img src="{x}" width="100"/>'
})
# Display the table in Jupyter Notebook
from IPython.display import display, HTML
display(HTML(df.to_html(escape=False, formatters={
    'Foot Scan Image': lambda x: f'<img src="{x}" width="100"/>',
    'Insole Image': lambda x: f'<img src="{x}" width="100"/>'
})))
# Out:
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/291631652.py:157: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['Subfolder', 'Foot Scan', 'Foot Scan Image', 'Insole', 'Insole Image'], dtype='object')]
#
#   df.to_hdf(hdf5_path, key='data', mode='w')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Subfolder</th>
#       <th>Foot Scan</th>
#       <th>Foot Scan Image</th>
#       <th>Insole</th>
#       <th>Insole Image</th>
#       <th>Foot Length</th>
#       <th>Foot Width</th>
#       <th>Foot Height</th>
#       <th>Foot Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Anonymous_20240507043443</td>
#       <td>31e01ae6-bc67-4235-b1c6-944f8c325729_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/31e01ae6-bc67-4235-b1c6-944f8c325729_0_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>246.220482</td>
#       <td>98.687160</td>
#       <td>50.116524</td>
#       <td>685916.257100</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Anonymous_20240507043443</td>
#       <td>0169f5c3-dc66-4de0-8e71-d2108dbabe63_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/0169f5c3-dc66-4de0-8e71-d2108dbabe63_1_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>242.586243</td>
#       <td>98.942276</td>
#       <td>50.403454</td>
#       <td>701255.889287</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Anonymous_20240506033002</td>
#       <td>3414bbfe-685b-4462-8071-05ef9d40ce0f_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/3414bbfe-685b-4462-8071-05ef9d40ce0f_0_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>234.057808</td>
#       <td>92.513699</td>
#       <td>28.666253</td>
#       <td>21815.959887</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Anonymous_20240506033002</td>
#       <td>132b9f60-57bb-4e44-b480-0cad7abd106c_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/132b9f60-57bb-4e44-b480-0cad7abd106c_1_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>229.371590</td>
#       <td>85.996262</td>
#       <td>33.755031</td>
#       <td>29972.094611</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Anonymous_20240507025604</td>
#       <td>13e80473-7d0b-4d2b-aad0-53550c5eda9b_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507025604/13e80473-7d0b-4d2b-aad0-53550c5eda9b_0_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>256.039490</td>
#       <td>91.555882</td>
#       <td>36.582973</td>
#       <td>46328.524155</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Anonymous_20240507025604</td>
#       <td>c3a2d5ce-1750-41d8-aa4b-eac754ed53e6_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507025604/c3a2d5ce-1750-41d8-aa4b-eac754ed53e6_1_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>241.652771</td>
#       <td>110.635677</td>
#       <td>54.769722</td>
#       <td>86008.301317</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Anonymous_20240506021423</td>
#       <td>7cdc0bf2-0f5d-4567-be3d-2bd4793c3f6f_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506021423/7cdc0bf2-0f5d-4567-be3d-2bd4793c3f6f_1_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>260.731010</td>
#       <td>100.715412</td>
#       <td>44.422279</td>
#       <td>611914.467397</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Anonymous_20240506021423</td>
#       <td>d44c0998-ab31-49bc-962e-3f917657c518_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506021423/d44c0998-ab31-49bc-962e-3f917657c518_0_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>259.839996</td>
#       <td>101.027649</td>
#       <td>54.319935</td>
#       <td>723751.948250</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Anonymous_20240504091729</td>
#       <td>d6aa477e-1290-4dba-a505-8191078fcecf_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240504091729/d6aa477e-1290-4dba-a505-8191078fcecf_1_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>188.808228</td>
#       <td>92.419464</td>
#       <td>21.511803</td>
#       <td>14008.826206</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Anonymous_20240504091729</td>
#       <td>d165fd5b-659b-4b39-9c06-f057a4330eae_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240504091729/d165fd5b-659b-4b39-9c06-f057a4330eae_0_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>194.438606</td>
#       <td>96.737133</td>
#       <td>17.632964</td>
#       <td>10268.210545</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Anonymous_20240504063416</td>
#       <td>5095faf0-a5d5-4b30-8466-2a41db2c8e3a_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240504063416/5095faf0-a5d5-4b30-8466-2a41db2c8e3a_0_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>241.789108</td>
#       <td>93.345959</td>
#       <td>60.065952</td>
#       <td>143296.333190</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Anonymous_20240504063416</td>
#       <td>9846eae2-3bb3-42ca-8378-b3fb43416d69_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240504063416/9846eae2-3bb3-42ca-8378-b3fb43416d69_1_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>234.280556</td>
#       <td>91.043495</td>
#       <td>49.034473</td>
#       <td>150384.741453</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Anonymous_20240505012721</td>
#       <td>a02cd3a0-64a9-4a99-949a-34717ef11622_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505012721/a02cd3a0-64a9-4a99-949a-34717ef11622_1_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>239.640083</td>
#       <td>95.060848</td>
#       <td>43.533865</td>
#       <td>80080.612115</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Anonymous_20240505012721</td>
#       <td>eb2d4d46-d390-4609-bcf3-c967639bd057_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505012721/eb2d4d46-d390-4609-bcf3-c967639bd057_0_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>239.357880</td>
#       <td>94.041767</td>
#       <td>43.711342</td>
#       <td>67841.791292</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Anonymous_20240505104102</td>
#       <td>399ca224-d17e-49b5-868e-d39ecfa9fb47_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505104102/399ca224-d17e-49b5-868e-d39ecfa9fb47_0_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>216.772934</td>
#       <td>136.328026</td>
#       <td>104.607819</td>
#       <td>343192.429111</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Anonymous_20240505104102</td>
#       <td>ef00b58d-4093-4183-a314-032ee7f21315_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505104102/ef00b58d-4093-4183-a314-032ee7f21315_1_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>196.825821</td>
#       <td>171.399902</td>
#       <td>103.164551</td>
#       <td>279747.826897</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Anonymous_20240506104517</td>
#       <td>6e15c2f3-651d-

# %%
import pyvista as pv
import numpy as np
import os
import pandas as pd

def extract_geometric_features(stl_path):
    try:
        # Load the STL file
        mesh = pv.read(stl_path)
        
        # Get the bounding box dimensions
        bounds = mesh.bounds
        length = bounds[1] - bounds[0]
        width = bounds[3] - bounds[2]
        height = bounds[5] - bounds[4]
        
        # Calculate the volume
        volume = mesh.volume
        
        return {
            'Length': length,
            'Width': width,
            'Height': height,
            'Volume': volume
        }
    except Exception as e:
        print(f"Error extracting features from {stl_path}: {e}")
        return None

def is_valid_foot_scan(features):
    # Define thresholds for valid foot scans
    min_length = 100  # Example threshold in mm
    max_length = 400  # Example threshold in mm
    min_width = 50    # Example threshold in mm
    max_width = 200   # Example threshold in mm
    min_height = 10   # Example threshold in mm
    max_height = 200  # Example threshold in mm
    min_volume = 1000  # Example threshold in cubic mm
    max_volume = 1000000  # Example threshold in cubic mm
    
    if (min_length <= features['Length'] <= max_length and
        min_width <= features['Width'] <= max_width and
        min_height <= features['Height'] <= max_height and
        min_volume <= features['Volume'] <= max_volume):
        return True
    return False

def visualize_and_save_screenshot(mesh, output_path):
    try:
        # Create a Plotter with off-screen rendering enabled
        plotter = pv.Plotter(off_screen=True)
        
        # Add the mesh to the plotter
        plotter.add_mesh(mesh)
        
        # Save a screenshot
        plotter.screenshot(output_path)
        
        # Close the plotter
        plotter.close()
    except Exception as e:
        print(f"Error visualizing mesh: {e}")

# Base directory containing subfolders
base_dir = '/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011'

# Data structure to store information for the table
data = []

# Iterate over each subfolder in the base directory
for subfolder in os.listdir(base_dir):
    subfolder_path = os.path.join(base_dir, subfolder)
    if os.path.isdir(subfolder_path):
        foot_scans = [f for f in os.listdir(subfolder_path) if f.endswith('.stl') and not f.endswith('library.stl')]

        # Check for valid foot scans
        for foot_scan in foot_scans:
            foot_scan_path = os.path.join(subfolder_path, foot_scan)
            features = extract_geometric_features(foot_scan_path)
            if features and is_valid_foot_scan(features):
                foot_scan_img = os.path.join(subfolder_path, f'{foot_scan}.png')
                mesh = pv.read(foot_scan_path)
                visualize_and_save_screenshot(mesh, foot_scan_img)
                data.append({
                    'Subfolder': subfolder,
                    'Foot Scan': foot_scan,
                    'Foot Scan Image': foot_scan_img,
                    'Insole': None,
                    'Insole Image': None,
                    'Foot Length': features['Length'],
                    'Foot Width': features['Width'],
                    'Foot Height': features['Height'],
                    'Foot Volume': features['Volume']
                })

                # Visualize insoles in the same folder
                insoles = [f for f in os.listdir(subfolder_path) if f.endswith('library.stl')]
                for insole in insoles:
                    insole_path = os.path.join(subfolder_path, insole)
                    insole_img = os.path.join(subfolder_path, f'{insole}.png')
                    mesh = pv.read(insole_path)
                    visualize_and_save_screenshot(mesh, insole_img)
                    data.append({
                        'Subfolder': subfolder,
                        'Foot Scan': None,
                        'Foot Scan Image': None,
                        'Insole': insole,
                        'Insole Image': insole_img,
                        'Foot Length': None,
                        'Foot Width': None,
                        'Foot Height': None,
                        'Foot Volume': None
                    })

# Create a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to CSV, HDF5, and pickle files
csv_path = 'filtered_foot_scan_insole_table.csv'
df.to_csv(csv_path, index=False)

hdf5_path = 'filtered_foot_scan_insole_table.h5'
df.to_hdf(hdf5_path, key='data', mode='w')

pickle_path = 'filtered_foot_scan_insole_table.pkl'
df.to_pickle(pickle_path)

# Save the DataFrame as an HTML file
html_path = os.path.join(base_dir, 'filtered_foot_scan_insole_table.html')
df.to_html(html_path, escape=False, formatters={
    'Foot Scan Image': lambda x: f'<img src="{x}" width="100"/>',
    'Insole Image': lambda x: f'<img src="{x}" width="100"/>'
})
# Display the table in Jupyter Notebook
from IPython.display import display, HTML
display(HTML(df.to_html(escape=False, formatters={
    'Foot Scan Image': lambda x: f'<img src="{x}" width="100"/>',
    'Insole Image': lambda x: f'<img src="{x}" width="100"/>'
})))
# Out:
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1209809669.py:123: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['Subfolder', 'Foot Scan', 'Foot Scan Image', 'Insole', 'Insole Image'], dtype='object')]
#
#   df.to_hdf(hdf5_path, key='data', mode='w')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Subfolder</th>
#       <th>Foot Scan</th>
#       <th>Foot Scan Image</th>
#       <th>Insole</th>
#       <th>Insole Image</th>
#       <th>Foot Length</th>
#       <th>Foot Width</th>
#       <th>Foot Height</th>
#       <th>Foot Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Anonymous_20240507043443</td>
#       <td>31e01ae6-bc67-4235-b1c6-944f8c325729_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/31e01ae6-bc67-4235-b1c6-944f8c325729_0_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>246.220482</td>
#       <td>98.687160</td>
#       <td>50.116524</td>
#       <td>685916.257100</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Anonymous_20240507043443</td>
#       <td>None</td>
#       <td>None</td>
#       <td>67_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/67_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Anonymous_20240507043443</td>
#       <td>None</td>
#       <td>None</td>
#       <td>49_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/49_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Anonymous_20240507043443</td>
#       <td>None</td>
#       <td>None</td>
#       <td>29_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/29_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Anonymous_20240507043443</td>
#       <td>None</td>
#       <td>None</td>
#       <td>91_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/91_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Anonymous_20240507043443</td>
#       <td>0169f5c3-dc66-4de0-8e71-d2108dbabe63_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/0169f5c3-dc66-4de0-8e71-d2108dbabe63_1_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>242.586243</td>
#       <td>98.942276</td>
#       <td>50.403454</td>
#       <td>701255.889287</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Anonymous_20240507043443</td>
#       <td>None</td>
#       <td>None</td>
#       <td>67_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/67_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Anonymous_20240507043443</td>
#       <td>None</td>
#       <td>None</td>
#       <td>49_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/49_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Anonymous_20240507043443</td>
#       <td>None</td>
#       <td>None</td>
#       <td>29_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/29_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Anonymous_20240507043443</td>
#       <td>None</td>
#       <td>None</td>
#       <td>91_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/91_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Anonymous_20240506033002</td>
#       <td>3414bbfe-685b-4462-8071-05ef9d40ce0f_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/3414bbfe-685b-4462-8071-05ef9d40ce0f_0_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>234.057808</td>
#       <td>92.513699</td>
#       <td>28.666253</td>
#       <td>21815.959887</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Anonymous_20240506033002</td>
#       <td>None</td>
#       <td>None</td>
#       <td>26_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/26_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Anonymous_20240506033002</td>
#       <td>None</td>
#       <td>None</td>
#       <td>67_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/67_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Anonymous_20240506033002</td>
#       <td>None</td>
#       <td>None</td>
#       <td>49_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/49_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Anonymous_20240506033002</td>
#       <td>None</td>
#       <td>None</td>
#       <td>1_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/1_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Anonymous_20240506033002</td>
#       <td>None</td>
#       <td>None</td>
#       <td>19_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/19_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Anonymous_20240506033002</td>
#       <td>None</td>
#       <td>None</td>
#       <td>22_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/22_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Anonymous_20240506033002</td>
#       <td>None</td>
#       <td>None</td>
#       <td>28_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/28_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Anonymous_20240506033002</td>
#       <td>132b9f60-57bb-4e44-b480-0cad7abd106c_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/132b9f60-57bb-4e44-b480-0cad7abd106c_1_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>229.371590</td>
#       <td>85.996262</td>
#       <td>33.755031</td>
#       <td>29972.094611</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Anonymous_20240506033002</td>
#       <td>None</td>
#       <td>None</td>
#       <td>26_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anon

# %% [markdown]
# DROPPING OUT THE INVALID INSOLES

# %%
import pyvista as pv
import numpy as np
import os
import pandas as pd

def extract_geometric_features(stl_path):
    try:
        # Load the STL file
        mesh = pv.read(stl_path)
        
        # Get the bounding box dimensions
        bounds = mesh.bounds
        length = bounds[1] - bounds[0]
        width = bounds[3] - bounds[2]
        height = bounds[5] - bounds[4]
        
        # Calculate the volume
        volume = mesh.volume
        
        return {
            'Length': length,
            'Width': width,
            'Height': height,
            'Volume': volume
        }
    except Exception as e:
        print(f"Error extracting features from {stl_path}: {e}")
        return None

def is_valid_foot_scan(features):
    # Define thresholds for valid foot scans
    min_length = 100  # Example threshold in mm
    max_length = 400  # Example threshold in mm
    min_width = 50    # Example threshold in mm
    max_width = 200   # Example threshold in mm
    min_height = 10   # Example threshold in mm
    max_height = 200  # Example threshold in mm
    min_volume = 1000  # Example threshold in cubic mm
    max_volume = 1000000  # Example threshold in cubic mm
    
    if (min_length <= features['Length'] <= max_length and
        min_width <= features['Width'] <= max_width and
        min_height <= features['Height'] <= max_height and
        min_volume <= features['Volume'] <= max_volume):
        return True
    return False

def visualize_and_save_screenshot(mesh, output_path):
    try:
        # Create a Plotter with off-screen rendering enabled
        plotter = pv.Pplotter(off_screen=True)
        
        # Add the mesh to the plotter
        plotter.add_mesh(mesh)
        
        # Save a screenshot
        plotter.screenshot(output_path)
        
        # Close the plotter
        plotter.close()
    except Exception as e:
        print(f"Error visualizing mesh: {e}")

# Base directory containing subfolders
base_dir = '/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011'

# Data structure to store information for the table
data = []

# Iterate over each subfolder in the base directory
for subfolder in os.listdir(base_dir):
    subfolder_path = os.path.join(base_dir, subfolder)
    if os.path.isdir(subfolder_path):
        foot_scans = [f for f in os.listdir(subfolder_path) if f.endswith('.stl') and not f.endswith('library.stl')]

        # Check for valid foot scans
        for foot_scan in foot_scans:
            foot_scan_path = os.path.join(subfolder_path, foot_scan)
            features = extract_geometric_features(foot_scan_path)
            if features and is_valid_foot_scan(features):
                foot_scan_img = os.path.join(subfolder_path, f'{foot_scan}.png')
                mesh = pv.read(foot_scan_path)
                visualize_and_save_screenshot(mesh, foot_scan_img)
                data.append({
                    'Subfolder': subfolder,
                    'Foot Scan': foot_scan,
                    'Foot Scan Image': foot_scan_img,
                    'Insole': None,
                    'Insole Image': None,
                    'Foot Length': features['Length'],
                    'Foot Width': features['Width'],
                    'Foot Height': features['Height'],
                    'Foot Volume': features['Volume']
                })

                # Visualize insoles in the same folder
                insoles = [f for f in os.listdir(subfolder_path) if f.endswith('library.stl')]
                for insole in insoles:
                    insole_path = os.path.join(subfolder_path, insole)
                    insole_img = os.path.join(subfolder_path, f'{insole}.png')
                    mesh = pv.read(insole_path)
                    visualize_and_save_screenshot(mesh, insole_img)
                    data.append({
                        'Subfolder': subfolder,
                        'Foot Scan': None,
                        'Foot Scan Image': None,
                        'Insole': insole,
                        'Insole Image': insole_img,
                        'Foot Length': None,
                        'Foot Width': None,
                        'Foot Height': None,
                        'Foot Volume': None
                    })

# Create a DataFrame
df = pd.DataFrame(data)

# Indices of rows to be dropped
rows_to_drop = [3, 4, 8, 9, 11, 14, 15, 16, 17, 19, 22, 23, 24, 25, 41, 45, 53, 54, 55, 57, 60, 61, 62, 64, 68, 87, 88, 92, 93, 97, 100, 102, 105, 108, 110, 113, 115, 119, 123, 132, 136, 139, 141, 144, 146, 150, 159, 163]

# Drop the specified rows
df.drop(rows_to_drop, inplace=True)

# Save the DataFrame to CSV, HDF5, and pickle files
csv_path = 'filtered_foot_scan_insole_table.csv'
df.to_csv(csv_path, index=False)

hdf5_path = 'filtered_foot_scan_insole_table.h5'
df.to_hdf(hdf5_path, key='data', mode='w')

pickle_path = 'filtered_foot_scan_insole_table.pkl'
df.to_pickle(pickle_path)

# Save the DataFrame as an HTML file
html_path = os.path.join(base_dir, 'filtered_foot_scan_insole_table.html')
df.to_html(html_path, escape=False, formatters={
    'Foot Scan Image': lambda x: f'<img src="{x}" width="100"/>',
    'Insole Image': lambda x: f'<img src="{x}" width="100"/>'
})
# Display the table in Jupyter Notebook
from IPython.display import display, HTML
display(HTML(df.to_html(escape=False, formatters={
    'Foot Scan Image': lambda x: f'<img src="{x}" width="100"/>',
    'Insole Image': lambda x: f'<img src="{x}" width="100"/>'
})))
# Out:
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# Error visualizing mesh: module 'pyvista' has no attribute 'Pplotter'
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/3462021471.py:129: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['Subfolder', 'Foot Scan', 'Foot Scan Image', 'Insole', 'Insole Image'], dtype='object')]
#
#   df.to_hdf(hdf5_path, key='data', mode='w')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Subfolder</th>
#       <th>Foot Scan</th>
#       <th>Foot Scan Image</th>
#       <th>Insole</th>
#       <th>Insole Image</th>
#       <th>Foot Length</th>
#       <th>Foot Width</th>
#       <th>Foot Height</th>
#       <th>Foot Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Anonymous_20240507043443</td>
#       <td>31e01ae6-bc67-4235-b1c6-944f8c325729_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/31e01ae6-bc67-4235-b1c6-944f8c325729_0_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>246.220482</td>
#       <td>98.687160</td>
#       <td>50.116524</td>
#       <td>685916.257100</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Anonymous_20240507043443</td>
#       <td>None</td>
#       <td>None</td>
#       <td>67_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/67_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Anonymous_20240507043443</td>
#       <td>None</td>
#       <td>None</td>
#       <td>49_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/49_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Anonymous_20240507043443</td>
#       <td>0169f5c3-dc66-4de0-8e71-d2108dbabe63_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/0169f5c3-dc66-4de0-8e71-d2108dbabe63_1_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>242.586243</td>
#       <td>98.942276</td>
#       <td>50.403454</td>
#       <td>701255.889287</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Anonymous_20240507043443</td>
#       <td>None</td>
#       <td>None</td>
#       <td>67_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/67_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Anonymous_20240507043443</td>
#       <td>None</td>
#       <td>None</td>
#       <td>49_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507043443/49_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Anonymous_20240506033002</td>
#       <td>3414bbfe-685b-4462-8071-05ef9d40ce0f_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/3414bbfe-685b-4462-8071-05ef9d40ce0f_0_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>234.057808</td>
#       <td>92.513699</td>
#       <td>28.666253</td>
#       <td>21815.959887</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Anonymous_20240506033002</td>
#       <td>None</td>
#       <td>None</td>
#       <td>67_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/67_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Anonymous_20240506033002</td>
#       <td>None</td>
#       <td>None</td>
#       <td>49_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/49_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Anonymous_20240506033002</td>
#       <td>132b9f60-57bb-4e44-b480-0cad7abd106c_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/132b9f60-57bb-4e44-b480-0cad7abd106c_1_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>229.371590</td>
#       <td>85.996262</td>
#       <td>33.755031</td>
#       <td>29972.094611</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Anonymous_20240506033002</td>
#       <td>None</td>
#       <td>None</td>
#       <td>67_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/67_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Anonymous_20240506033002</td>
#       <td>None</td>
#       <td>None</td>
#       <td>49_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506033002/49_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Anonymous_20240507025604</td>
#       <td>13e80473-7d0b-4d2b-aad0-53550c5eda9b_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507025604/13e80473-7d0b-4d2b-aad0-53550c5eda9b_0_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>256.039490</td>
#       <td>91.555882</td>
#       <td>36.582973</td>
#       <td>46328.524155</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Anonymous_20240507025604</td>
#       <td>None</td>
#       <td>None</td>
#       <td>67_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507025604/67_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Anonymous_20240507025604</td>
#       <td>None</td>
#       <td>None</td>
#       <td>49_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507025604/49_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Anonymous_20240507025604</td>
#       <td>c3a2d5ce-1750-41d8-aa4b-eac754ed53e6_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507025604/c3a2d5ce-1750-41d8-aa4b-eac754ed53e6_1_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>241.652771</td>
#       <td>110.635677</td>
#       <td>54.769722</td>
#       <td>86008.301317</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>Anonymous_20240507025604</td>
#       <td>None</td>
#       <td>None</td>
#       <td>67_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507025604/67_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Anonymous_20240507025604</td>
#       <td>None</td>
#       <td>None</td>
#       <td>49_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240507025604/49_library.stl.png" width="100"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Anonymous_20240506021423</td>
#       <td>7cdc0bf2-0f5d-4567-be3d-2bd4793c3f6f_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240506021423/7cdc0bf2-0f5d-4567-be3d-2bd4793c3f6f_1_document.stl.png" width="100"/></td>
#       <td>None</td>
#       <td>None</td>
#       <td>260.731010</td

# %%
import pyvista as pv
import numpy as np
import os
import pandas as pd

def extract_geometric_features(stl_path):
    try:
        # Load the STL file
        mesh = pv.read(stl_path)
        
        # Get the bounding box dimensions
        bounds = mesh.bounds
        length = bounds[1] - bounds[0]
        width = bounds[3] - bounds[2]
        height = bounds[5] - bounds[4]
        
        # Calculate the volume
        volume = mesh.volume
        
        return {
            'Length': length,
            'Width': width,
            'Height': height,
            'Volume': volume
        }
    except Exception as e:
        print(f"Error extracting features from {stl_path}: {e}")
        return None

def is_valid_foot_scan(features):
    # Define thresholds for valid foot scans
    min_length = 100  # Example threshold in mm
    max_length = 400  # Example threshold in mm
    min_width = 50    # Example threshold in mm
    max_width = 200   # Example threshold in mm
    min_height = 10   # Example threshold in mm
    max_height = 200  # Example threshold in mm
    min_volume = 1000  # Example threshold in cubic mm
    max_volume = 1000000  # Example threshold in cubic mm
    
    if (min_length <= features['Length'] <= max_length and
        min_width <= features['Width'] <= max_width and
        min_height <= features['Height'] <= max_height and
        min_volume <= features['Volume'] <= max_volume):
        return True
    return False

def visualize_and_save_screenshot(mesh, output_path):
    try:
        # Create a Plotter with off-screen rendering enabled
        plotter = pv.Plotter(off_screen=True)
        
        # Add the mesh to the plotter
        plotter.add_mesh(mesh)
        
        # Save a screenshot
        plotter.screenshot(output_path)
        
        # Close the plotter
        plotter.close()
    except Exception as e:
        print(f"Error visualizing mesh: {e}")

# Base directory containing subfolders
base_dir = '/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011'

# Data structure to store information for the table
data = []

# Iterate over each subfolder in the base directory
for subfolder in os.listdir(base_dir):
    subfolder_path = os.path.join(base_dir, subfolder)
    if os.path.isdir(subfolder_path):
        foot_scans = [f for f in os.listdir(subfolder_path) if f.endswith('.stl') and not f.endswith('library.stl')]

        # Check for valid foot scans
        for foot_scan in foot_scans:
            foot_scan_path = os.path.join(subfolder_path, foot_scan)
            features = extract_geometric_features(foot_scan_path)
            if features and is_valid_foot_scan(features):
                foot_scan_img = os.path.join(subfolder_path, f'{foot_scan}.png')
                mesh = pv.read(foot_scan_path)
                visualize_and_save_screenshot(mesh, foot_scan_img)
                data.append({
                    'Subfolder': subfolder,
                    'Foot Scan': foot_scan,
                    'Foot Scan Image': foot_scan_img,
                    'Insole': None,
                    'Insole Image': None,
                    'Foot Length': features['Length'],
                    'Foot Width': features['Width'],
                    'Foot Height': features['Height'],
                    'Foot Volume': features['Volume']
                })

                # Visualize insoles in the same folder
                insoles = [f for f in os.listdir(subfolder_path) if f.endswith('library.stl')]
                for insole in insoles:
                    insole_path = os.path.join(subfolder_path, insole)
                    insole_img = os.path.join(subfolder_path, f'{insole}.png')
                    mesh = pv.read(insole_path)
                    visualize_and_save_screenshot(mesh, insole_img)
                    data.append({
                        'Subfolder': subfolder,
                        'Foot Scan': None,
                        'Foot Scan Image': None,
                        'Insole': insole,
                        'Insole Image': insole_img,
                        'Foot Length': None,
                        'Foot Width': None,
                        'Foot Height': None,
                        'Foot Volume': None
                    })

# Create a DataFrame
df = pd.DataFrame(data)

# Indices of rows to be dropped
rows_to_drop = [3, 4, 8, 9, 11, 14, 15, 16, 17, 19, 22, 23, 24, 25, 41, 45, 53, 54, 55, 57, 60, 61, 62, 64, 68, 87, 88, 92, 93, 97, 100, 102, 105, 108, 110, 113, 115, 119, 123, 132, 136, 139, 141, 144, 146, 150, 159, 163]

# Drop the specified rows
df.drop(rows_to_drop, inplace=True)

# Function to find the best fitting insoles based on length and width
def find_best_insoles(foot_scan_row, insole_rows):
    # Sort insole rows by length and width difference to the foot scan
    insole_rows['Length Diff'] = abs(insole_rows['Foot Length'] - foot_scan_row['Foot Length'])
    insole_rows['Width Diff'] = abs(insole_rows['Foot Width'] - foot_scan_row['Foot Width'])
    insole_rows = insole_rows.sort_values(by=['Length Diff', 'Width Diff'])
    
    # Return the best two insoles
    return insole_rows.head(2)

# Merge foot scans with the best two insoles in each subfolder
merged_data = []
for subfolder, group in df.groupby('Subfolder'):
    foot_scan_rows = group[group['Foot Scan'].notnull()]
    insole_rows = group[group['Insole'].notnull()]
    
    if not foot_scan_rows.empty and not insole_rows.empty:
        foot_scan_row = foot_scan_rows.iloc[0]  # Assuming only one valid foot scan per subfolder
        best_insoles = find_best_insoles(foot_scan_row, insole_rows)
        
        for _, insole_row in best_insoles.iterrows():
            merged_data.append({
                'Subfolder': subfolder,
                'Foot Scan': foot_scan_row['Foot Scan'],
                'Foot Scan Image': foot_scan_row['Foot Scan Image'],
                'Insole': insole_row['Insole'],
                'Insole Image': insole_row['Insole Image'],
                'Foot Length': foot_scan_row['Foot Length'],
                'Foot Width': foot_scan_row['Foot Width'],
                'Foot Height': foot_scan_row['Foot Height'],
                'Foot Volume': foot_scan_row['Foot Volume']
            })

# Create a merged DataFrame
merged_df = pd.DataFrame(merged_data)

# Save the merged DataFrame to CSV, HDF5, and pickle files
csv_path = 'merged_foot_scan_insole_table.csv'
merged_df.to_csv(csv_path, index=False)

hdf5_path = 'merged_foot_scan_insole_table.h5'
merged_df.to_hdf(hdf5_path, key='data', mode='w')

pickle_path = 'merged_foot_scan_insole_table.pkl'
merged_df.to_pickle(pickle_path)

# Save the merged DataFrame as an HTML file
html_path = os.path.join(base_dir, 'merged_foot_scan_insole_table.html')
merged_df.to_html(html_path, escape=False, formatters={
    'Foot Scan Image': lambda x: f'<img src="{x}" width="100"/>',
    'Insole Image': lambda x: f'<img src="{x}" width="100"/>'
})
# Display the table in Jupyter Notebook
from IPython.display import display, HTML
display(HTML(merged_df.to_html(escape=False, formatters={
    'Foot Scan Image': lambda x: f'<img src="{x}" width="100"/>',
    'Insole Image': lambda x: f'<img src="{x}" width="100"/>'
})))
# Out:
# 2024-06-10 12:38:02.573 python[1831:62128] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x126e86320 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.573 python[1831:62119] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x126e88da0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.573 python[1831:62128] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x146fad800 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.574 python[1831:62119] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x1478481b0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.609 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x146f7ad80 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.611 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x146fba3c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.640 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x146fb2780 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.642 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x146fba3c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.670 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x146fbb870 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.671 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x146fc66e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.700 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x146fc66e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.701 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x146fc02e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.742 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x106f8c280 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.743 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x106f5fa10 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.772 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x146fbe540 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.774 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x146fe2410 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.802 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x146fb96e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.804 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x146fec670 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.832 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef521ab0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-10 12:38:02.834 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef51c850 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.861 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef54ce60 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.863 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef547b40 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.917 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x331e89920 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.919 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x331e9ee70 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.951 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x331ed9da0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.952 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x331ed4a80 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.984 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x331ed86b0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:02.986 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x331e9aa10 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.016 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5d2a20 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.017 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5a9100 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Context leak detected, msgtracer returned -1
# 2024-06-10 12:38:03.050 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4d9504450 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.051 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5b10b0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-10 12:38:03.081 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4f4599150 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.083 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4f456a560 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.111 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x147868190 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.113 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5742d0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.144 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef59b720 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.145 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x14786b780 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.178 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5de5a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.180 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5de5a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.208 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5d52f0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.209 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5d52c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.241 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5ff320 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.242 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5ff4e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.272 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef597df0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.274 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef597df0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.303 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5943a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.304 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5943a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.332 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5fe970 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.333 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5943a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.361 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5943a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-10 12:38:03.363 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5f8bc0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.391 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5f8bc0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.392 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5ed810 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.427 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5ff710 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.428 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5ed810 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.460 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5ff710 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.461 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4ef5ed810 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.490 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x505944fc0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.492 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x50593fbe0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.527 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x51beed630 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.529 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x51bed1840 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.559 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x505980930 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.561 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x505980930 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.589 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x51becc980 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.590 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x51bece5a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-10 12:38:03.673 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x5059abc70 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.675 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x5059de7d0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.708 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x5059de7d0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.710 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x5059dd0e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.741 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x5059e1c40 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.743 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x5059e56a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.783 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x5238d3aa0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.784 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x5238ad990 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.814 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x5059eaa00 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.816 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x5059d1a10 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.846 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b0311a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.848 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b02bec0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.880 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b0311a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.881 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b025c70 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Context leak detected, msgtracer returned -1
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-10 12:38:03.910 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b02bec0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.911 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b025420 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.940 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b025c70 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.941 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b02fb40 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.969 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b05b710 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:03.970 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b057970 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.002 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b0500e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.004 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b05a0b0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.033 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b05a0b0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.035 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b0500e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.068 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b05b710 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.069 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b0500e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.098 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b085c90 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.099 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b0808b0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.132 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b08a1a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.134 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b070830 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-10 12:38:04.164 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b0757a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.166 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b074640 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.195 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b075da0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.196 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b072250 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.230 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b0ade40 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.232 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b0b0770 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.263 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x1478806a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.265 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b0b0770 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.293 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b0e0bb0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.294 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x147880820 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.360 python[1831:62117] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x52b0fe560 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-10 12:38:04.362 python[1831:62126] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x147880910 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# ...
#   insole_rows['Length Diff'] = abs(insole_rows['Foot Length'] - foot_scan_row['Foot Length'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Width Diff'] = abs(insole_rows['Foot Width'] - foot_scan_row['Foot Width'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Length Diff'] = abs(insole_rows['Foot Length'] - foot_scan_row['Foot Length'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Width Diff'] = abs(insole_rows['Foot Width'] - foot_scan_row['Foot Width'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Length Diff'] = abs(insole_rows['Foot Length'] - foot_scan_row['Foot Length'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Width Diff'] = abs(insole_rows['Foot Width'] - foot_scan_row['Foot Width'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Length Diff'] = abs(insole_rows['Foot Length'] - foot_scan_row['Foot Length'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Width Diff'] = abs(insole_rows['Foot Width'] - foot_scan_row['Foot Width'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Length Diff'] = abs(insole_rows['Foot Length'] - foot_scan_row['Foot Length'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Width Diff'] = abs(insole_rows['Foot Width'] - foot_scan_row['Foot Width'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Length Diff'] = abs(insole_rows['Foot Length'] - foot_scan_row['Foot Length'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Width Diff'] = abs(insole_rows['Foot Width'] - foot_scan_row['Foot Width'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Length Diff'] = abs(insole_rows['Foot Length'] - foot_scan_row['Foot Length'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Width Diff'] = abs(insole_rows['Foot Width'] - foot_scan_row['Foot Width'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Length Diff'] = abs(insole_rows['Foot Length'] - foot_scan_row['Foot Length'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Width Diff'] = abs(insole_rows['Foot Width'] - foot_scan_row['Foot Width'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Length Diff'] = abs(insole_rows['Foot Length'] - foot_scan_row['Foot Length'])
# /var/folders/x6/vrfll5sx3fbbylywk6w9s0c00000gn/T/ipykernel_1831/1007584053.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insole_rows['Width Diff'] = abs(insole_rows['Foot Width'] - foot_scan_row['Foot Width'])
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Subfolder</th>
#       <th>Foot Scan</th>
#       <th>Foot Scan Image</th>
#       <th>Insole</th>
#       <th>Insole Image</th>
#       <th>Foot Length</th>
#       <th>Foot Width</th>
#       <th>Foot Height</th>
#       <th>Foot Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Anonymous_20240504063416</td>
#       <td>5095faf0-a5d5-4b30-8466-2a41db2c8e3a_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240504063416/5095faf0-a5d5-4b30-8466-2a41db2c8e3a_0_document.stl.png" width="100"/></td>
#       <td>110_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240504063416/110_library.stl.png" width="100"/></td>
#       <td>241.789108</td>
#       <td>93.345959</td>
#       <td>60.065952</td>
#       <td>143296.333190</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Anonymous_20240504063416</td>
#       <td>5095faf0-a5d5-4b30-8466-2a41db2c8e3a_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240504063416/5095faf0-a5d5-4b30-8466-2a41db2c8e3a_0_document.stl.png" width="100"/></td>
#       <td>111_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240504063416/111_library.stl.png" width="100"/></td>
#       <td>241.789108</td>
#       <td>93.345959</td>
#       <td>60.065952</td>
#       <td>143296.333190</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Anonymous_20240504091729</td>
#       <td>d6aa477e-1290-4dba-a505-8191078fcecf_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240504091729/d6aa477e-1290-4dba-a505-8191078fcecf_1_document.stl.png" width="100"/></td>
#       <td>323_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240504091729/323_library.stl.png" width="100"/></td>
#       <td>188.808228</td>
#       <td>92.419464</td>
#       <td>21.511803</td>
#       <td>14008.826206</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Anonymous_20240504091729</td>
#       <td>d6aa477e-1290-4dba-a505-8191078fcecf_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240504091729/d6aa477e-1290-4dba-a505-8191078fcecf_1_document.stl.png" width="100"/></td>
#       <td>95_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240504091729/95_library.stl.png" width="100"/></td>
#       <td>188.808228</td>
#       <td>92.419464</td>
#       <td>21.511803</td>
#       <td>14008.826206</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Anonymous_20240505011213</td>
#       <td>b5dd7895-d5d5-4efe-a61c-ac7d4e8a8b02_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505011213/b5dd7895-d5d5-4efe-a61c-ac7d4e8a8b02_1_document.stl.png" width="100"/></td>
#       <td>110_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505011213/110_library.stl.png" width="100"/></td>
#       <td>174.000092</td>
#       <td>177.685318</td>
#       <td>106.051407</td>
#       <td>308680.599246</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Anonymous_20240505011213</td>
#       <td>b5dd7895-d5d5-4efe-a61c-ac7d4e8a8b02_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505011213/b5dd7895-d5d5-4efe-a61c-ac7d4e8a8b02_1_document.stl.png" width="100"/></td>
#       <td>111_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505011213/111_library.stl.png" width="100"/></td>
#       <td>174.000092</td>
#       <td>177.685318</td>
#       <td>106.051407</td>
#       <td>308680.599246</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Anonymous_20240505012721</td>
#       <td>a02cd3a0-64a9-4a99-949a-34717ef11622_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505012721/a02cd3a0-64a9-4a99-949a-34717ef11622_1_document.stl.png" width="100"/></td>
#       <td>110_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505012721/110_library.stl.png" width="100"/></td>
#       <td>239.640083</td>
#       <td>95.060848</td>
#       <td>43.533865</td>
#       <td>80080.612115</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Anonymous_20240505012721</td>
#       <td>a02cd3a0-64a9-4a99-949a-34717ef11622_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505012721/a02cd3a0-64a9-4a99-949a-34717ef11622_1_document.stl.png" width="100"/></td>
#       <td>111_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505012721/111_library.stl.png" width="100"/></td>
#       <td>239.640083</td>
#       <td>95.060848</td>
#       <td>43.533865</td>
#       <td>80080.612115</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Anonymous_20240505021004</td>
#       <td>43876342-f1c8-49a8-b267-7074ed0ffa7b_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505021004/43876342-f1c8-49a8-b267-7074ed0ffa7b_1_document.stl.png" width="100"/></td>
#       <td>110_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505021004/110_library.stl.png" width="100"/></td>
#       <td>218.210449</td>
#       <td>87.431496</td>
#       <td>33.045457</td>
#       <td>56013.801947</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Anonymous_20240505021004</td>
#       <td>43876342-f1c8-49a8-b267-7074ed0ffa7b_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505021004/43876342-f1c8-49a8-b267-7074ed0ffa7b_1_document.stl.png" width="100"/></td>
#       <td>111_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505021004/111_library.stl.png" width="100"/></td>
#       <td>218.210449</td>
#       <td>87.431496</td>
#       <td>33.045457</td>
#       <td>56013.801947</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Anonymous_20240505054445</td>
#       <td>9dcd743c-fd7a-4a1d-94f5-6511ad0b13c7_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505054445/9dcd743c-fd7a-4a1d-94f5-6511ad0b13c7_1_document.stl.png" width="100"/></td>
#       <td>110_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505054445/110_library.stl.png" width="100"/></td>
#       <td>253.454079</td>
#       <td>101.588551</td>
#       <td>65.816990</td>
#       <td>410550.089582</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Anonymous_20240505054445</td>
#       <td>9dcd743c-fd7a-4a1d-94f5-6511ad0b13c7_1_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505054445/9dcd743c-fd7a-4a1d-94f5-6511ad0b13c7_1_document.stl.png" width="100"/></td>
#       <td>111_library.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505054445/111_library.stl.png" width="100"/></td>
#       <td>253.454079</td>
#       <td>101.588551</td>
#       <td>65.816990</td>
#       <td>410550.089582</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Anonymous_20240505095828</td>
#       <td>38bfc854-bd9a-418c-966d-5d40c3be7fec_0_document.stl</td>
#       <td><img src="/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011/Anonymous_20240505095828/38bfc854-bd9a-418c-966d-5d40c3be7fec_0_document.stl.png" width="100"/></td>
#       <
