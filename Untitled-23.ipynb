# %%
import pyvista as pv
import numpy as np
import os
import pandas as pd

def extract_geometric_features(stl_path):
    try:
        # Load the STL file
        mesh = pv.read(stl_path)
        
        # Get the bounding box dimensions
        bounds = mesh.bounds
        length = bounds[1] - bounds[0]
        width = bounds[3] - bounds[2]
        height = bounds[5] - bounds[4]
        
        # Calculate the volume
        volume = mesh.volume
        
        return {
            'Length': length,
            'Width': width,
            'Height': height,
            'Volume': volume
        }
    except Exception as e:
        print(f"Error extracting features from {stl_path}: {e}")
        return None

def is_valid_foot_scan(features):
    # Define thresholds for valid foot scans
    min_length = 100  # Example threshold in mm
    max_length = 400  # Example threshold in mm
    min_width = 50    # Example threshold in mm
    max_width = 200   # Example threshold in mm
    min_height = 10   # Example threshold in mm
    max_height = 200  # Example threshold in mm
    min_volume = 1000  # Example threshold in cubic mm
    max_volume = 1000000  # Example threshold in cubic mm
    
    if (min_length <= features['Length'] <= max_length and
        min_width <= features['Width'] <= max_width and
        min_height <= features['Height'] <= max_height and
        min_volume <= features['Volume'] <= max_volume):
        return True
    return False

def visualize_and_save_screenshot(mesh, output_path):
    try:
        # Create a Plotter with off-screen rendering enabled
        plotter = pv.Plotter(off_screen=True)
        
        # Add the mesh to the plotter
        plotter.add_mesh(mesh)
        
        # Save a screenshot
        plotter.screenshot(output_path)
        
        # Close the plotter
        plotter.close()
    except Exception as e:
        print(f"Error visualizing mesh: {e}")

# Base directory containing subfolders
base_dir = '/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240505095828'

# Data structure to store information for the table
data = []

# Iterate over each subfolder in the base directory
for subfolder in os.listdir(base_dir):
    subfolder_path = os.path.join(base_dir, subfolder)
    if os.path.isdir(subfolder_path):
        foot_scans = [f for f in os.listdir(subfolder_path) if f.endswith('.stl') and not f.endswith('library.stl')]

        # Check for valid foot scans
        for foot_scan in foot_scans:
            foot_scan_path = os.path.join(subfolder_path, foot_scan)
            features = extract_geometric_features(foot_scan_path)
            if features and is_valid_foot_scan(features):
                foot_scan_img = os.path.join(subfolder_path, f'{foot_scan}.png')
                mesh = pv.read(foot_scan_path)
                visualize_and_save_screenshot(mesh, foot_scan_img)
                
                # Find all the insoles in the same folder
                insoles = [f for f in os.listdir(subfolder_path) if f.endswith('library.stl')]
                insole_images = []
                for insole in insoles:
                    insole_path = os.path.join(subfolder_path, insole)
                    insole_img = os.path.join(subfolder_path, f'{insole}.png')
                    mesh = pv.read(insole_path)
                    visualize_and_save_screenshot(mesh, insole_img)
                    insole_images.append(insole_img)

                data.append({
                    'Subfolder': subfolder,
                    'Foot Scan': foot_scan,
                    'Foot Scan Image': foot_scan_img,
                    'Insole': ', '.join(insoles),
                    'Insole Images': ', '.join(insole_images),
                    'Foot Length': features['Length'],
                    'Foot Width': features['Width'],
                    'Foot Height': features['Height'],
                    'Foot Volume': features['Volume']
                })

# Create a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to CSV, HDF5, and pickle files
csv_path = 'all_insoles_foot_scan_table.csv'
df.to_csv(csv_path, index=False)

hdf5_path = 'all_insoles_foot_scan_table.h5'
df.to_hdf(hdf5_path, key='data', mode='w')

pickle_path = 'all_insoles_foot_scan_table.pkl'
df.to_pickle(pickle_path)

# Save the DataFrame as an HTML file
html_path = 'all_insoles_foot_scan_table.html'
df.to_html(html_path, escape=False, formatters={
    'Foot Scan Image': lambda x: f'<img src="{x}" width="100"/>',
    'Insole Images': lambda x: '<br>'.join([f'<img src="{img}" width="100"/>' for img in x.split(', ')])
})

# Display the table in Jupyter Notebook
from IPython.display import display, HTML
display(HTML(df.to_html(escape=False, formatters={
    'Foot Scan Image': lambda x: f'<img src="{x}" width="100"/>',
    'Insole Images': lambda x: '<br>'.join([f'<img src="{img}" width="100"/>' for img in x.split(', ')])
})))
# Out:
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# 2024-06-13 14:00:27.284 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3d10bef10 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.287 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3d1047210 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.365 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3d10b33e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.369 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3d107d2b0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.400 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x34348eb20 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.402 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3d10da250 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.433 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x177838e10 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.435 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3c6fb1590 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.465 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed145b10 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.466 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ee975cc0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.500 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3434e17a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.502 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed128700 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-13 14:00:27.532 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed12a120 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.534 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed12a120 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.565 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed12a120 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.566 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed12a120 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.597 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed12d670 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.599 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed12a120 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.642 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4014b06c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.644 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed12dca0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.677 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3c6fff950 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.681 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x406430050 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.718 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3c7026700 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.721 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x40648b650 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-13 14:00:27.764 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1756a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.766 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4014b02c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.801 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x40145b730 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.803 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x40145b730 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.834 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1a8d50 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.836 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x406481fe0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Context leak detected, msgtracer returned -1
# 2024-06-13 14:00:27.879 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1b0450 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.881 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1b0630 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Context leak detected, msgtracer returned -1
# 2024-06-13 14:00:27.918 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1df450 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.920 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1da170 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.948 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1da170 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.950 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1df450 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-13 14:00:27.979 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1dddf0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:27.980 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1da170 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.015 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1c88c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.017 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1f5720 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.047 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1f93a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.049 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1f5720 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.080 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1c88c0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.081 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1f93a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.113 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4166c7c30 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.115 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4166c7d60 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.158 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x416720af0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.160 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x416710e00 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.189 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x41670d9e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.190 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1cbed0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.221 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x41670d730 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.223 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1cbed0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.251 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x41670d730 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-13 14:00:28.253 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4064c1170 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.284 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x416710e00 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.285 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1fbd20 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.319 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x40647c270 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.321 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3c70619f0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.351 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1cbed0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.355 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3ed1cbed0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.390 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3c70aa6e0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.392 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3c70a9a20 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.424 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x440e41c90 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.426 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x440e11c80 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.458 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x440e42030 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.460 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4064daca0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.501 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x3c709ba30 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# Error visualizing mesh: Render window is not current.
# 2024-06-13 14:00:28.503 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x440e79720 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.534 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4167683a0 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.536 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x41676da10 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.565 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x440ed9c70 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.567 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x440ea6150 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.595 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4167afc00 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.597 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x416746d00 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.629 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x416746d00 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.631 python[1987:22060] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4167afc00 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28.662 python[1987:21958] GLDRendererMetal command buffer completion error: Error Domain=MTLCommandBufferErrorDomain Code=8 "Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory)" UserInfo={NSLocalizedDescription=Insufficient Memory (00000008:kIOGPUCommandBufferCallbackErrorOutOfMemory), NSUnderlyingError=0x4167e2940 {Error Domain=IOGPUCommandQueueErrorDomain Code=8 "(null)"}}
# 2024-06-13 14:00:28