# %%
import os 
import pandas as pd
import numpy as np
from stl import mesh
import json

#directory containing the folders 
base_dir ='/Users/elvisechefu/Desktop/LutraCAD2/Anonymous_20240507025011'

#Initialize an empty list to store the data
data = []

#Loop throigh each folder
for folder in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, folder)
    if os.path.isdir(folder_path):
        #initializing a directory to store details for the current folder 
        folder_data = {'Folder Number': folder}
        
        #Process TXT file
        txt_file_path = None
        for file in os.listdir(folder_path):
            if file.endswith('.txt'):
                txt_file_path = os.path.join(folder_path, file)
                break 
            if txt_file_path:
                with open(txt_file_path, 'r') as file:
                    details = {}
                    for line in file :
                        key, value = line.strip().split(':')
                        details[key.strip()] = value.strip()
                    folder_data.update({
                        'MTP1': details.get('MTP1'),
                        'MTP5': details.get('MTP5'),
                        'HEEL': details.get('HEEL'),
                        'ARCH': details.get('ARCH'),
                        'ANKLE MEDIAL': details.get('ANKLE MEDIAL'),
                        'ANKLE LATERAL': details.get('ANKLE LATERAL'),
                        'LENGTH (TXT)': details.get('LENGTH'),
                        'WIDTH (TXT)': details.get('WIDTH')
                    })
        
        # Process STL files
        stl_files = [f for f in os.listdir(folder_path) if f.endswith('.stl') and f != 'library.stl']
        for stl_file in stl_files:
            stl_file_path = os.path.join(folder_path, stl_file)
            stl_mesh = mesh.Mesh.from_file(stl_file_path)
            bounding_box_dimensions = stl_mesh.points.ptp(axis=0)
            volume, cog, inertia = stl_mesh.get_mass_properties()
            surface_area = sum(np.linalg.norm(np.cross(v0 - v1, v0 - v2)) / 2 for v0, v1, v2 in stl_mesh.vectors)
            if 'foot' in stl_file.lower():
                folder_data.update({
                    'Foot Scan STL File Name': os.path.basename(stl_file_path),
                    'Foot Scan Bounding Box Dimensions': bounding_box_dimensions,
                    'Foot Scan Surface Area': surface_area,
                    'Foot Scan Center of Mass': cog
                })
            else:
                folder_data['Insole STL File Name'] = os.path.basename(stl_file_path)
            
        #Process action.dat files
        action_file_path = os.path.join(folder_path, 'action.dat')
        if os.path.isfile(action_file_path):
            with open(action_file_path, 'r') as file:
                actions
# Out:
# Your mesh is not closed, the mass methods will not function
#         correctly on this mesh.  For more info:
#         https://github.com/WoLpH/numpy-stl/issues/69
# Your mesh is not closed, the mass methods will not function
#         correctly on this mesh.  For more info:
#         https://github.com/WoLpH/numpy-stl/issues/69
# Your mesh is not closed, the mass methods will not function
#         correctly on this mesh.  For more info:
#         https://github.com/WoLpH/numpy-stl/issues/69
# Your mesh is not closed, the mass methods will not function
#         correctly on this mesh.  For more info:
#         https://github.com/WoLpH/numpy-stl/issues/69
# Your mesh is not closed, the mass methods will not function
#         correctly on this mesh.  For more info:
#         https://github.com/WoLpH/numpy-stl/issues/69
# Your mesh is not closed, the mass methods will not function
#         correctly on this mesh.  For more info:
# ...
